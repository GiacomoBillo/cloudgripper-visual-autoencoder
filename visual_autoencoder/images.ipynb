# %%
from data import load_data

# %% [markdown]
# Load data

# %%
experiment = "data_collection_clean_env"
sessions = ["1","2"]
bottom_images, top_images, states = load_data(experiment, sessions, verbose=True)
# Out:
# ...
# 100%|██████████| 809/809 [00:09<00:00, 87.43it/s]
# Recording session 1
# Bottom images -> type: <class 'numpy.ndarray'>, len: (809, 480, 640, 3)
# Top images -> type: <class 'numpy.ndarray'>, len: (809, 1280, 720, 3)
# States -> type: <class 'list'>, len: 809
# ...
# 100%|██████████| 3958/3958 [01:58<00:00, 33.34it/s]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 experiment = "data_collection_clean_env"
#       2 sessions = ["1","2"]
# ----> 3 bottom_images, top_images, states = load_data(experiment, sessions, verbose=True)
#
# File d:\Jack\KTH\Research project in Robotics\cloudgripper-visual-autoencoder\visual_autoencoder\data.py:75, in load_data(experiment, sessions, verbose)
#      72 new_top_images = load_images(top_images_path)
#      73 new_states = load_states(states_path)
# ---> 75 if verbose:
# ...
